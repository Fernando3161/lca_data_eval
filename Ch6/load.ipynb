# %%
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
sns.set_style("darkgrid")
time = ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00']
load = [6.67, 6.12, 5.62, 4.77, 4.39, 4.04, 5.68, 12.48, 17.25, 14.91, 13.25, 12.18, 10.86, 9.85, 8.94, 9.99, 12.58, 21.61, 23.11, 19.01, 17.47, 14.43, 11.76, 8.17]

plt.plot(time, load)
plt.title('Electricity Load Profile for Building of 6 Apartments in Germany')
plt.xlabel('Time (hour)')
plt.ylabel('Electricity Load (kWh)')
plt.xticks(rotation=90)

plt.show()
